# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Itzam Adrián Morales**
# My current ocupation right now it's about to manage exports in a company that process marble, we extract the marble from our own cuarries. And we are selling to many countries around the world.
# My desire ocupation is to know more about data science and could explore this world and make profit and a potential life activitie for my future family.

# %% [markdown]
# *I am interested in Data Science because match perfectly with my analitical point of wiew about the different aspects that surround us. And how is important to make a mesurment of those aspects and most important what that data says about our customs, this information is very important in order to discover new patterns, new hidden facts that are happening and sometimes we are not able realize. Also this information could help to find new medical solutions, best make decision making.*

# %% [markdown]
# ### In the next cell you will show the result of add two numbers

# %%
3+9
# Out:
# 12

# %% [markdown]
# My hobbies
# * Collect toys
# * Hearing good quialitie music
# * Camping in motorcycle
#
# The three next places I like to visit in my motorcycle
# 1. Xemuc Champei, Coban
# 2. Laguna Brava, Huehuetenango
# 3. Playa del Carmen, Cancún
#
# |Client|Country|Status|
# |-------|-------|------|
# |The new book|Belgium| Shipp book|
# |Readfun|Germany| Negotiation started|
# |Artemis Edinter|Guatemala|Present diverse option books|
#
# ### Now take a look of one my favorite games
# ![wallpaperflare.com_wallpaper.jpg](attachment:wallpaperflare.com_wallpaper.jpg)
